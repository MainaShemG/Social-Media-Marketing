# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('Whatsgoodly - Thought Catalog Influencers.csv')
df
# Out:
#                                                Question Segment Type  \
# 0     What do you think when an influencer is obviou...       Mobile
# 1     What do you think when an influencer is obviou...       Mobile
# 2     What do you think when an influencer is obviou...       Mobile
# 3     What do you think when an influencer is obviou...       Mobile
# 4     What do you think when an influencer is obviou...          Web
# ...                                                 ...          ...
# 5455                What do you consider an influencer?       Custom
# 5456                What do you consider an influencer?       Custom
# 5457                What do you consider an influencer?       Custom
# 5458                What do you consider an influencer?       Custom
# 5459                What do you consider an influencer?       Custom
#
#                Segment Description  \
# 0                   Global results
# 1                   Global results
# ...

# %%
df.columns
# Out:
# Index(['Question', 'Segment Type', 'Segment Description', 'Answer', 'Count',
#        'Percentage'],
#       dtype='object')

# %%
df
